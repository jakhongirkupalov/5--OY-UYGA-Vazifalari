# %% [markdown]
# # Bias - Mitigation - bu ML modellarida nohaqliklarni kamaytirish usullarining majmuasi

# %% [markdown]
# # Bias - qaysi joylarda keladi --> // Odatda 3 ta joyda buni aniqlash mumkin
# - Dataning o'zi bias bo'lishi
# -- Dataset inbalance -- notekis
#
#
# - Model bias bo'lishi
# -- model juda sodda yoki notogri
# -- featurelar notogri tanlangan
#
# - Evaluationda(modelni baxolash)da bias bo'lishi
# -- noto'gri metrik tanlash
# -- faqat accuracy bilan ko'rish noto'gri

# %% [markdown]
# # Bias Mitigationni kamaytirish bosqichlari
#
# - Data bilan
# -- Re sampling
# -- Re waiting
# -- Sensitive featurelarni boshqarish

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(class_weight="balanced")
model.fit(x_train, y_train)

# %% [markdown]
# # inprocessing -- model ichida
#
# - fairness canstraint qo'shish
# - regularization
# - adversial debiasing

# %% [markdown]
# # Post processing -- modeldan keyin
#
# - natijalar kuzatamiz
# - thresholdni o'zgartirish
# - outputlarni balanslash

# %% [markdown]
# # Fairness Matriclar
# -- Biasni o'lchash uchun
# - Demographic Party
# - Equal Opportunity
# - Equalized Odds

# %% [markdown]
# # Bias - variance - ML da modelning qanchalik tog'ri va barqaror ishlashini tushuntiradigan eng muxim tushuncha

# %% [markdown]
# # bias -
# model juda sodda (underfitting)
# # variance - model juda murakkab (overfitting)

# %% [markdown]
# # Bias- bu  modelning real hayotdagi datani togri o'rganolmasligi
# - model juda sodda boladi
# - patternlarni tushunmaydi

# %% [markdown]
# # Belgilari
# - train accuracy past chiqadi
# - test accuracy ham past chiqadi
# - model hatolik bilan taxmin qiladi

# %% [markdown]
# # Variance - modelning dataga haddan tashqari yopishib olishi
# - model train datani yodlab olgan bo'ladi
# - yangi data berilganda yiqiladi

# %% [markdown]
# # Variancening belgilari
# - train accuracy yuqori chiqadi
# - test accuracy past chiqadi

# %% [markdown]
# # BIAS- VARIANCE TRADE OFF - bu bias va variance muvozanatda saqlasj tartibi

# %% [markdown]
# # Bias kamaytirsak --> Variance oshadi
# # Variance kamaytirsak --> Bias oshadi

# %% [markdown]
# # Xulosa
#
# - BIAS = noto'gri soddalashtirish
# - Variance = ortiqcha murakkablik
# - Eng yaxshi model = balance
